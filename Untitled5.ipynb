# %% [markdown]
# <a href="https://colab.research.google.com/github/SUBHASH-KANDHWAY/MACHINE-LEARNING-PROJECTS/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:, -1].values
print(X)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:, 2] = le.fit_transform(X[:, 2])
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %% [markdown]
# BUILDIG THE ANN

# %% [markdown]
# 1. INITIALIZE THE ANN

# %%
ANN=tf.keras.models.Sequential()

# %% [markdown]
# 2.ADDING THE INPUT LAYER AND HIDDEN LAYER

# %%
ANN.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %% [markdown]
# 3.ADDING THE SECOND LAYER

# %%
ANN.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %% [markdown]
# 4. ADDING THE OUTPUT

# %%
ANN.add(tf.keras.layers.Dense(units=1,activation='relu'))

# %%
ANN.add(tf.keras.layers.Dense(units=6,activation='sigoid'))

# %% [markdown]
# COMPILATION

# %%
ANN.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# TRAINING THE SET

# %%
ANN.fit(X_train,y_train,batch_size=256,epochs=750)
# Out:
# Epoch 1/750
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7521 - accuracy: 0.0129
# Epoch 2/750
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7251 - accuracy: 0.0000e+00
# Epoch 3/750
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7177 - accuracy: 0.0000e+00
# Epoch 4/750
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7129 - accuracy: 0.0000e+00
# Epoch 5/750
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7091 - accuracy: 0.0000e+00
# Epoch 6/750
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7060 - accuracy: 0.0000e+00
# Epoch 7/750
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7037 - accuracy: 0.0000e+00
# Epoch 8/750
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7020 - accuracy: 0.0000e+00
# Epoch 9/750
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7009 - accuracy: 0.0000e+00
# Epoch 10/750
# ...

# %%
print(ANN.predict(sc.transform([[1,0,0,600,1,40,3,60000,2,1,1,50000]]))>0.5)
# Out:
# [[False False False False False False]]

# %%
print(ann.predict(sc.transform([[1, 0, 0, 600, 1, 40, 3, 60000, 2, 1, 1, 50000]])) > 0.5)

# %%
y_pred = ANN.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
